# %% [markdown]
# <a href="https://colab.research.google.com/github/huylc12343/DAY01_2A202601165_NguyenQuangHuy/blob/main/colab/Lab21_RUN_ALL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lab 21 — Fine-tuning LLMs · RUN ALL (T4)
#
# Chay tu tren xuong. Runtime > Change runtime type > **T4 GPU** truoc khi bat dau.
#
# | O | Lam gi | Thoi gian |
# |---|---|---|
# | 1 | clone + install | ~1 phut |
# | 2 | smoke: import + unit test | ~30 giay |
# | 3 | **core pipeline NB1 -> NB5** | ~80 phut |
# | 4 | gatekeeper + in ket qua | ~10 giay |

# %%
# @title 1. Setup — clone + install (chạy ô này trước)
import os, subprocess, sys

REPO = "https://github.com/hieutrungdao/Day21-Track3-Finetuning-Lab.git"
if not os.path.exists("Day21-Track3-Finetuning-Lab"):
    subprocess.run(["git", "clone", "-q", REPO], check=True)
os.chdir("/content/Day21-Track3-Finetuning-Lab")
subprocess.run(["git", "pull", "-q"], check=False)
sys.path.insert(0, "src")

# Install from requirements.txt, NOT a copied list. The copied list is how the
# torchao>=0.16 pin reached requirements.txt and this bootstrap on different days --
# and a bootstrap missing a pin does not fail here, it fails 10 minutes later inside
# get_peft_model(). One source of truth. torch is preinstalled on Colab and
# requirements.txt pins it compatibly, so that line is a no-op.
subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"],
               check=True)

import torch
print("commit :", subprocess.run(["git","rev-parse","--short","HEAD"],
                                 capture_output=True, text=True).stdout.strip())
print("GPU    :", torch.cuda.get_device_name(0) if torch.cuda.is_available()
      else "NONE — Runtime > Change runtime type > T4 GPU")
if torch.cuda.is_available():
    print("VRAM   : %.1f GB" % (torch.cuda.get_device_properties(0).total_memory/1024**3))
# Out:
# commit : 4f619a4
# GPU    : NVIDIA A100-SXM4-40GB
# VRAM   : 39.5 GB

# %%
# @title 2. Smoke — imports, seed data, unit tests (no GPU needed)
# !python scripts/verify.py --smoke
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    T4 -> unsloth/Qwen3.5-4B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.28s
#
# 6 passed · 0 warnings · 1 failures
#
# Not ready to submit — fix the FAILs above.

# %%
# @title 3. Core pipeline — NB1 → NB5
# EVAL_LIMIT truncates both eval sets: "" = full run (submittable),
# 8 = ~fast smoke pass. STAGES lets you resume after a failure.
import os
COMPUTE_TIER = "BIGGPU"      # @param ["CPU","LAPTOP","T4","BIGGPU"]
EVAL_LIMIT   = "8"         # @param ["", "4", "8", "16", "25"]
STAGES       = "nb1 nb2 nb3 nb4 nb5"   # @param {type:"string"}

os.environ["COMPUTE_TIER"] = COMPUTE_TIER
if EVAL_LIMIT:
    os.environ["EVAL_LIMIT"] = EVAL_LIMIT
else:
    os.environ.pop("EVAL_LIMIT", None)

from labkit import device
print(device.banner(), "\n")

# !python scripts/colab_run.py {STAGES}
# Out:
# NVIDIA A100-SXM4-40GB (cuda, sm_80, 39.5 GB) -> precision=bf16
#
# tier=BIGGPU  mask=assistant-only  eval_limit=8
#
# ========================================================================
# NB1 — data, chat template & loss mask
# ========================================================================
# tier=BIGGPU  model=Qwen/Qwen3.5-9B  max_length=2048
# 250 mẫu huấn luyện
# {
#   "instruction": "Phân loại ticket chăm sóc khách hàng sau thành JSON với đúng 4 khóa: intent, urgency, product, sentiment. Chỉ trả về JSON, không giải thích.\n\nintent thuộc: doi_tra | van_chuyen | hoan_tien | san_pham_loi | hoi_thong_tin\nurgency thuộc: cao | trung_binh | thap\nsentiment thuộc: tieu_cuc | trung_tinh | tich_cuc\nproduct: tên sản phẩm xuất hiện trong ticket.",
#   "input": "Alo sh
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 3.13k/3.13k [00:00<00:00, 9.64MB/s]
# tokenizer_config.json: 100% 16.7k/16.7k [00:00<00:00, 40.8MB/s]
# vocab.json: 100% 6.72M/6.72M [00:00<00:00, 95.6MB/s]
# merges.txt: 100% 3.35M/3.35M [00:00<00:00, 121MB/s]
#
# tokenizer.json: downloading bytes:   0% 0.00/12.8M [00:00<?, ?B/s]
# tokenizer.json: downloading bytes: 100% 5.68M/5.68M [00:00<00:00, 8.70MB/s,  562kB/s  ]
# tokenizer.json: reconstructing file: 100% 12.8M/12.8M [00:00<00:00, 19.6MB/s, 1.27MB/s  ]
# chat_template.jinja: 100% 7.76k/7.76k [00:00<00:00, 19.0MB/s]
# eos_token: <|im_end|>
# VERDICT: reasoning preserved — safe to train on traces
#
# --- chuỗi đã render ---
# <|im_start|>user
# 2+2?<|im_end|>
# <|im_start|>assistant
# <think>
# buoc 1: kiem tra. buoc 2: tra loi.
# </think>
#
# 4<|im_end|>
#
# ======================================================================
# mode = assistant-only   supervised 39/94 (41%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# ======================================================================
# mode = everything   supervised 94/94 (100%)
# --- LOSS TÍNH TRÊN ĐOẠN NÀY ---
# <|im_start|>system
# Phân loại ticket sau.<|im_end|>
# <|im_start|>user
# Alo shop, mình đặt balo laptop mã đơn VN411453. Cho tôi trả lại. Đã 3 ngày rồi. Cho tôi hỏi.<|im_end|>
# <|im_start|>assistant
# <think>
#
# </think>
#
# {"intent": "doi_tra", "urgency": "trung_binh", "product": "balo laptop", "sentiment": "trung_tinh"}<|im_end|>
#
# {
#   "mask_mode": "assistant-only",
#   "n_supervised": 39,
#   "n_total": 94,
#   "supervised_fraction": 0.4149,
#   "answer_is_supervised": true,
#   "question_is_masked": true
# }
# {
#   "n": 250,
#   "mean": 93.1,
#   "p50": 93,
#   "p95": 98,
#   "p99": 100,
#   "max": 101,
#   "suggested_max_length": 256
# }
#
# ⚠ p95 gợi ý max_length=256 nhưng tier đang đặt 2048. Ghi lại lựa chọn của bạn trong REPORT.md.
# train=225  val=25  -> /content/Day21-Track3-Finetuning-Lab/data/split
#
# -- NB1 ok in 19s
#
# ========================================================================
# NB2 — freeze eval + three baselines
# ========================================================================
# ⚠ EVAL_LIMIT=8 — SMOKE MODE, not a submittable run
# target=8  regression=8  tier=BIGGPU
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# model.safetensors.index.json: 100% 79.7k/79.7k [00:00<00:00, 148MB/s]
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files:   0% 0/4 [00:00<?, ?it/s]
# Reconstructing (incomplete total...):   0% 0.00/8.69G [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/19.3G [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/19.3G [00:00<?, ?B/s]
# Reconstructing (incomplete total...):   0% 0.00/19.3G [00:00<?, ?B/s]
# Downloading bytes:   1% 181M/19.3G [00:00<01:08, 279MB/s,  211MB/s  ]
# Downloading bytes:   1% 247M/19.3G [00:01<01:03, 298MB/s,  279MB/s  ]
# Downloading bytes:   3% 530M/19.3G [00:02<01:24, 222MB/s,  212MB/s  ]
# Downloading bytes:   4% 710M/19.3G [00:03<01:00, 309MB/s,  290MB/s  ]
# Downloading bytes:   5% 901M/19.3G [00:03<00:45, 402MB/s,  373MB/s  ]
# Downloading bytes:   5% 946M/19.3G [00:03<00:45, 404MB/s,  402MB/s  ]
# Downloading bytes:   6% 1.13G/19.3G [00:04<00:42, 425MB/s,  416MB/s  ]
# Downloading bytes:   7% 1.40G/19.3G [00:04<00:32, 545MB/s,  529MB/s  ]
# Reconstructing (incomplete total...):   4% 805M/19.3G [00:04<01:28, 208MB/s,  223MB/s  ]
# Downloading bytes:   8% 1.60G/19.3G [00:05<00:37, 470MB/s,  434MB/s  ]
# Downloading bytes:   9% 1.79G/19.3G [00:05<00:39, 439MB/s,  534MB/s  ]
# Downloading bytes:  11% 2.06G/19.3G [00:06<00:45, 383MB/s,  364MB/s  ]
# Downloading bytes:  11% 2.11G/19.3G [00:06<00:43, 393MB/s,  383MB/s  ]
# Downloading bytes:  11% 2.19G/19.3G [00:06<00:57, 298MB/s,  289MB/s  ]
# Downloading bytes:  12% 2.40G/19.3G [00:07<00:37, 453MB/s,  439MB/s  ]
# Downloading bytes:  14% 2.64G/19.3G [00:07<00:27, 596MB/s,  548MB/s  ]
# Downloading bytes:  15% 2.91G/19.3G [00:07<00:20, 800MB/s,  725MB/s  ]
# Downloading bytes:  16% 3.00G/19.3G [00:07<00:20, 814MB/s,  800MB/s  ]
# Downloading bytes:  16% 3.13G/19.3G [00:08<00:21, 736MB/s,  814MB/s  ]
# Downloading bytes:  17% 3.29G/19.3G [00:08<00:21, 751MB/s,  751MB/s  ]
# Downloading bytes:  20% 3.79G/19.3G [00:08<00:16, 918MB/s,  876MB/s  ]
# Downloading bytes:  21% 4.01G/19.3G [00:09<00:25, 600MB/s,  668MB/s  ]
# Downloading bytes:  28% 5.36G/19.3G [00:11<00:23, 600MB/s,  587MB/s  ]
# Downloading bytes:  28% 5.50G/19.3G [00:12<00:26, 518MB/s,  523MB/s  ]
# Downloading bytes:  33% 6.37G/19.3G [00:13<00:21, 589MB/s,  556MB/s  ]
# Downloading bytes:  38% 7.29G/19.3G [00:15<00:38, 309MB/s,  301MB/s  ]
# Downloading bytes:  39% 7.51G/19.3G [00:16<01:03, 186MB/s,  210MB/s  ]
# Downloading bytes:  40% 7.65G/19.3G [00:17<00:51, 227MB/s,  208MB/s  ]
# Downloading bytes:  43% 8.36G/19.3G [00:20<01:45, 104MB/s,  151MB/s  ]
# Downloading bytes:  44% 8.41G/19.3G [00:20<01:36, 113MB/s,  103MB/s  ]
# Downloading bytes:  45% 8.63G/19.3G [00:21<00:38, 274MB/s,  318MB/s  ]
# Downloading bytes:  49% 9.52G/19.3G [00:23<00:34, 280MB/s,  328MB/s  ]
# Reconstructing (incomplete total...):  37% 7.21G/19.3G [00:23<00:45, 267MB/s,  394MB/s  ]
# Downloading bytes:  53% 10.2G/19.3G [00:25<00:17, 509MB/s,  524MB/s  ]
# Downloading bytes:  56% 10.9G/19.3G [00:27<00:47, 178MB/s,  243MB/s  ]
# Downloading bytes:  61% 11.7G/19.3G [00:30<00:56, 135MB/s,  168MB/s  ]
# Downloading bytes:  63% 12.1G/19.3G [00:33<00:29, 243MB/s,  230MB/s  ]
# Downloading bytes:  63% 12.2G/19.3G [00:33<00:29, 243MB/s,  222MB/s  ]
# Downloading bytes:  68% 13.2G/19.3G [00:35<00:19, 321MB/s,  364MB/s  ]
# Downloading bytes:  69% 13.3G/19.3G [00:36<00:17, 351MB/s,  345MB/s  ]
# Downloading bytes:  73% 14.1G/19.3G [00:37<00:07, 668MB/s,  801MB/s  ]
# Downloading bytes:  77% 14.8G/19.3G [00:39<00:36, 125MB/s,  203MB/s  ]
# Reconstructing (incomplete total...):  69% 13.3G/19.3G [00:40<00:20, 294MB/s,  493MB/s  ]
#
# Downloading bytes:  77% 14.8G/19.3G [00:40<00:41, 108MB/s,  110MB/s  ]
# Downloading bytes:  81% 15.6G/19.3G [00:43<00:37, 98.6MB/s,  110MB/s  ]
# Downloading bytes:  84% 16.2G/19.3G [00:46<00:15, 204MB/s,  459MB/s  ]
# Downloading bytes:  85% 16.4G/19.3G [00:46<00:10, 287MB/s,  323MB/s  ]
# Downloading bytes:  86% 16.5G/19.3G [00:48<00:24, 113MB/s, 95.5MB/s  ]
# Downloading bytes:  86% 16.6G/19.3G [00:48<00:20, 136MB/s,  113MB/s  ]
# Reconstructing (incomplete total...):  93% 18.0G/19.3G [00:49<00:02, 501MB/s,  548MB/s  ]
#
# Fetching 4 files:  50% 2/4 [00:49<00:44, 22.30s/it]
# Reconstructing (incomplete total...):  95% 18.3G/19.3G [00:50<00:02, 499MB/s,  501MB/s  ]
# Reconstructing (incomplete total...):  96% 18.5G/19.3G [00:52<00:02, 316MB/s,  499MB/s  ]
#
# Fetching 4 files:  75% 3/4 [00:52<00:13, 13.40s/it]
# Reconstructing (incomplete total...): 100% 19.3G/19.3G [00:52<00:00, 537MB/s,  316MB/s  ]
#
# Fetching 4 files: 100% 4/4 [00:52<00:00, 13.21s/it]
# Download complete: 100% 16.6G/16.6G [00:52<00:00, 136MB/s,  136MB/s  ]
# Download complete: 100% 16.6G/16.6G [00:52<00:00, 313MB/s,  136MB/s  ]
# Reconstruction complete: 100% 19.3G/19.3G [00:52<00:00, 365MB/s,  537MB/s  ]
# Loading weights: 100% 427/427 [00:04<00:00, 92.62it/s]
#   [(a) base + naive prompt/target] batch 1/2     12s elapsed  ~   12s left
#   [(a) base + naive prompt/target] batch 2/2     23s elapsed  ~    0s left
#   [(a) base + naive prompt/target] done: 8 prompts in 23s
#   [(a) base + naive prompt/regression] batch 1/2      7s elapsed  ~    7s left
#   [(a) base + naive prompt/regression] batch 2/2     13s elapsed  ~    0s left
#   [(a) base + naive prompt/regression] done: 8 prompts in 13s
# (a) base + naive prompt      target=0.000  regression=0.750  format=0.000  2868ms
#   [(b) base + optimized prompt/target] batch 1/2      3s elapsed  ~    3s left
#   [(b) base + optimized prompt/target] batch 2/2      6s elapsed  ~    0s left
#   [(b) base + optimized prompt/target] done: 8 prompts in 6s
#   [(b) base + optimized prompt/regression] batch 1/2      7s elapsed  ~    7s left
#   [(b) base + optimized prompt/regression] batch 2/2     13s elapsed  ~    0s left
#   [(b) base + optimized prompt/regression] done: 8 prompts in 13s
# (b) base + optimized prompt  target=0.844  regression=0.750  format=1.000  730ms
# {
#   "tier": "BIGGPU",
#   "model": "Qwen/Qwen3.5-9B",
#   "baseline_a": {
#     "target": 0.0,
#     "regression": 0.75,
#     "format": 0.0,
#     "latency_ms": 2868.300361374999,
#     "n": 8,
#     "extra": {}
#   },
#   "baseline_b": {
#     "target": 0.84375,
#     "regression": 0.75,
#     "format": 1.0,
#     "latency_ms": 729.8318604999992,
#     "n": 8,
#     "extra": {}
#   },
#   "optimized_prompt_sha": "719e74d3b6232053",
#   "n_target": 8,
#   "n_regression": 8,
#   "eval_limit": 8,
#   "smoke_mode": true
# }
#
# -- NB2 ok in 128s
#
# ========================================================================
# NB3 — train the correct configuration
# ========================================================================
# BIGGPU · Qwen/Qwen3.5-9B · all-linear · r=16 · LR 10x · 16-bit
# NVIDIA A100-SXM4-40GB (cuda, sm_80, 39.5 GB) -> precision=bf16
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 1407.13it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 427/427 [00:04<00:00, 93.41it/s]
# {
#   "num_hidden_layers": 32,
#   "full_attention_interval": 4,
#   "linear_num_key_heads": 16,
#   "layer_types": {
#     "linear_attention": 24,
#     "full_attention": 8
#   }
# }
# placement=text-linear  modules=['down_proj', 'gate_proj', 'in_proj_a', 'in_proj_b', 'in_proj_qkv', 'in_proj_z', 'k_proj', 'o_proj', 'out_proj', 'q_proj', 'up_proj', 'v_proj']
# trainable LoRA params ≈ 43.28 M
#     {'placement': 'text-linear', 'modules': 12, 'r': 16, 'trainable': 43278336}
#     {'placement': 'attn-only(q,v)', 'modules': 2, 'r': 16, 'trainable': 2228224}
#     {'placement': 'attn-only(q,v) matched', 'modules': 2, 'r': 311, 'trainable': 43311104}
# Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
# mask_mode = assistant-only   supervised 9014/20951 tokens (43.0%)
# epochs=2.0  ->  30 optimizer steps  (NB4 runs its contrasts at exactly this many)
# {
#   "output_dir": "/content/Day21-Track3-Finetuning-Lab/adapters/correct",
#   "max_length": "2048",
#   "per_device_train_batch_size": "2",
#   "gradient_accumulation_steps": "8",
#   "learning_rate": "0.0001",
#   "lr_scheduler_type": "cosine",
#   "num_train_epochs": "2.0",
#   "logging_steps": "5",
#   "save_strategy": "no",
#   "report_to": "none",
#   "seed": "42",
#   "packing": "False",
#   "loss_type": "chunked_nll",
#   "gradient_checkpointing": "True",
#   "warmup_steps": "3",
#   "bf16": "True",
#   "fp16": "False",
#   "padding_free": "False"
# }
# Truncating train dataset: 100% 225/225 [00:00<00:00, 10515.09 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 41109.88 examples/s]
# precision fix: {'precision': 'bf16', 'recast': 0}
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248044}.
# {'loss': '1.412', 'grad_norm': '3.436', 'learning_rate': '9.966e-05', 'entropy': '0.8776', 'num_tokens': '7479', 'mean_token_accuracy': '0.7528', 'epoch': '0.354'}
# {'loss': '0.2045', 'grad_norm': '1.07', 'learning_rate': '8.83e-05', 'entropy': '0.2272', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.9561', 'epoch': '0.708'}
# {'loss': '0.039', 'grad_norm': '0.2223', 'learning_rate': '6.434e-05', 'entropy': '0.05238', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9849', 'epoch': '1'}
# {'loss': '0.01709', 'grad_norm': '0.4374', 'learning_rate': '3.566e-05', 'entropy': '0.02918', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9947', 'epoch': '1.354'}
# {'loss': '0.008513', 'grad_norm': '0.1513', 'learning_rate': '1.17e-05', 'entropy': '0.01482', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9965', 'epoch': '1.708'}
# {'loss': '0.004863', 'grad_norm': '0.03201', 'learning_rate': '3.381e-07', 'entropy': '0.01022', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.998', 'epoch': '2'}
# {'train_runtime': '444.6', 'train_samples_per_second': '1.012', 'train_steps_per_second': '0.067', 'train_loss': '0.281', 'epoch': '2'}
# 100% 30/30 [07:24<00:00, 14.82s/it]
# train 445s  final loss 0.2810
# saved -> /content/Day21-Track3-Finetuning-Lab/adapters/correct
# {
#   "run": "correct",
#   "label": "all-linear · r=16 · LR 10x · 16-bit",
#   "tier": "BIGGPU",
#   "model": "Qwen/Qwen3.5-9B",
#   "precision": "bf16",
#   "placement": "text-linear",
#   "n_target_modules": 12,
#   "r": 16,
#   "lora_alpha": 32,
#   "learning_rate": 0.0001,
#   "load_in_4bit": false,
#   "trainable_params": 43278336,
#   "train_seconds": 445.0,
#   "peak_vram_gb": 23.26,
#   "final_loss": 0.281,
#   "mask_mode": "assistant-only",
#   "max_steps": 30
# }
#
# -- NB3 ok in 474s
#
# ========================================================================
# NB4 — three misconfiguration contrasts
# ========================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 1380.05it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 427/427 [00:04<00:00, 92.15it/s]
# | placement | modules | r | trainable |
# |---|---|---|---|
# | text-linear | 12 | 16 | 43278336 |
# | attn-only(q,v) | 2 | 16 | 2228224 |
# | attn-only(q,v) matched | 2 | 311 | 43311104 |
# ======================================================================
# RUN attn_only: q,v only · r=matched · LR 10x · 16-bit
#      Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 1273.51it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 427/427 [00:04<00:00, 93.93it/s]
#   train_ds: Dataset({
#     features: ['input_ids', 'labels', 'attention_mask'],
#     num_rows: 225
# })
#   matched rank for attn_only: r=311 (alpha=622)
# Truncating train dataset: 100% 225/225 [00:00<00:00, 11076.25 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 34081.56 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248044}.
# {'loss': '1.27', 'grad_norm': '3.857', 'learning_rate': '9.966e-05', 'entropy': '0.8407', 'num_tokens': '7479', 'mean_token_accuracy': '0.7748', 'epoch': '0.354'}
# {'loss': '0.2207', 'grad_norm': '1.392', 'learning_rate': '8.83e-05', 'entropy': '0.2651', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.9502', 'epoch': '0.708'}
# {'loss': '0.04115', 'grad_norm': '0.4052', 'learning_rate': '6.434e-05', 'entropy': '0.07135', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9876', 'epoch': '1'}
# {'loss': '0.01983', 'grad_norm': '0.4275', 'learning_rate': '3.566e-05', 'entropy': '0.02678', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.995', 'epoch': '1.354'}
# {'loss': '0.008303', 'grad_norm': '0.1418', 'learning_rate': '1.17e-05', 'entropy': '0.01902', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9978', 'epoch': '1.708'}
# {'loss': '0.004166', 'grad_norm': '0.07305', 'learning_rate': '3.381e-07', 'entropy': '0.01338', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9984', 'epoch': '2'}
# {'train_runtime': '388.3', 'train_samples_per_second': '1.236', 'train_steps_per_second': '0.077', 'train_loss': '0.2607', 'epoch': '2'}
# 100% 30/30 [06:28<00:00, 12.94s/it]
# ======================================================================
# RUN wrong_lr: all-linear · r=16 · LR 1x (full-FT scale) · 16-bit
#      Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 1418.79it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 427/427 [00:04<00:00, 92.11it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 11560.93 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 41985.96 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248044}.
# {'loss': '1.739', 'grad_norm': '4.055', 'learning_rate': '9.966e-06', 'entropy': '0.9248', 'num_tokens': '7479', 'mean_token_accuracy': '0.7095', 'epoch': '0.354'}
# {'loss': '1.592', 'grad_norm': '4.009', 'learning_rate': '8.83e-06', 'entropy': '0.9293', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.7262', 'epoch': '0.708'}
# {'loss': '1.292', 'grad_norm': '6.742', 'learning_rate': '6.434e-06', 'entropy': '0.9139', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.7834', 'epoch': '1'}
# {'loss': '0.9873', 'grad_norm': '3.779', 'learning_rate': '3.566e-06', 'entropy': '0.7921', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.8047', 'epoch': '1.354'}
# {'loss': '0.843', 'grad_norm': '3.555', 'learning_rate': '1.17e-06', 'entropy': '0.7247', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.8208', 'epoch': '1.708'}
# {'loss': '0.7876', 'grad_norm': '4.829', 'learning_rate': '3.381e-08', 'entropy': '0.7239', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.8287', 'epoch': '2'}
# {'train_runtime': '462.6', 'train_samples_per_second': '1.038', 'train_steps_per_second': '0.065', 'train_loss': '1.207', 'epoch': '2'}
# 100% 30/30 [07:42<00:00, 15.42s/it]
# ======================================================================
# RUN qlora: all-linear · r=16 · LR 10x · 4-bit QLoRA
#      The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 1229.55it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 427/427 [00:05<00:00, 84.69it/s]
# Truncating train dataset: 100% 225/225 [00:00<00:00, 11766.92 examples/s]
# Dropping fully masked examples from train dataset: 100% 225/225 [00:00<00:00, 41280.71 examples/s]
# [transformers] The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 248046, 'pad_token_id': 248044}.
# {'loss': '1.411', 'grad_norm': '4.875', 'learning_rate': '9.966e-05', 'entropy': '0.9161', 'num_tokens': '7479', 'mean_token_accuracy': '0.7318', 'epoch': '0.354'}
# {'loss': '0.1988', 'grad_norm': '0.9297', 'learning_rate': '8.83e-05', 'entropy': '0.2146', 'num_tokens': '1.49e+04', 'mean_token_accuracy': '0.9555', 'epoch': '0.708'}
# {'loss': '0.04307', 'grad_norm': '1.219', 'learning_rate': '6.434e-05', 'entropy': '0.05823', 'num_tokens': '2.095e+04', 'mean_token_accuracy': '0.9861', 'epoch': '1'}
# {'loss': '0.02018', 'grad_norm': '0.4922', 'learning_rate': '3.566e-05', 'entropy': '0.03246', 'num_tokens': '2.843e+04', 'mean_token_accuracy': '0.9925', 'epoch': '1.354'}
# {'loss': '0.01143', 'grad_norm': '0.2139', 'learning_rate': '1.17e-05', 'entropy': '0.02239', 'num_tokens': '3.59e+04', 'mean_token_accuracy': '0.9954', 'epoch': '1.708'}
# {'loss': '0.005044', 'grad_norm': '0.21', 'learning_rate': '3.381e-07', 'entropy': '0.01533', 'num_tokens': '4.19e+04', 'mean_token_accuracy': '0.9985', 'epoch': '2'}
# {'train_runtime': '492', 'train_samples_per_second': '0.976', 'train_steps_per_second': '0.061', 'train_loss': '0.2816', 'epoch': '2'}
# 100% 30/30 [08:11<00:00, 16.40s/it]
# | run | label | r | trainable_params | learning_rate | final_loss | train_seconds | peak_vram_gb |
# |---|---|---|---|---|---|---|---|
# | correct | all-linear · r=16 · LR 10x · 16-bit | 16 | 43278336 | 0.0001 | 0.281 | 445.0 | 23.26 |
# | attn_only | q,v only · r=matched · LR 10x · 16-bit | 311 | 43311104 | 0.0001 | 0.2607 | 388.6 | 23.28 |
# | wrong_lr | all-linear · r=16 · LR 1x (full-FT scale) · 16-bit | 16 | 43278336 | 1e-05 | 1.2069 | 463.0 | 23.26 |
# | qlora | all-linear · r=16 · LR 10x · 4-bit QLoRA | 16 | 43278336 | 0.0001 | 0.2816 | 492.4 | 13.3 |
#
# -- NB4 ok in 1395s
#
# ========================================================================
# NB5 — four-group eval + verdict
# ========================================================================
# baseline (b) target = 0.844 — đây là mốc phải vượt
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_cutlass_90a.abi3.so
# Failed to load /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so: Could not load this library: /usr/local/lib/python3.12/dist-packages/torchao/_C_mxfp8.cpython-310-x86_64-linux-gnu.so
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 1498.50it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 427/427 [00:04<00:00, 93.09it/s]
#   [ft/target] batch 1/2      5s elapsed  ~    5s left
#   [ft/target] batch 2/2     10s elapsed  ~    0s left
#   [ft/target] done: 8 prompts in 10s
#   [ft/regression] batch 1/2      8s elapsed  ~    8s left
#   [ft/regression] batch 2/2     17s elapsed  ~    0s left
#   [ft/regression] done: 8 prompts in 17s
# fine-tune: {'target': 1.0, 'regression': 0.25, 'format': 1.0, 'latency_ms': 1291.3329708749757, 'n': 8, 'extra': {'valid_trace_rate': 0.0}}
# | run | target | regression | format | latency_ms | n |
# |---|---|---|---|---|---|
# | (a) base + naive prompt | 0.0 | 0.75 | 0.0 | 2868.3 | 8 |
# | (b) base + optimized prompt | 0.8438 | 0.75 | 1.0 | 729.8 | 8 |
# | (c) LoRA fine-tune | 1.0 | 0.25 | 1.0 | 1291.3 | 8 |
# FAILED
#  - general capability regressed by 0.500 (tolerance 0.020). See deck §14.3 — add 1-5% replay data.
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 1219.90it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 427/427 [00:04<00:00, 93.99it/s]
#   [attn_only/target] batch 1/2      3s elapsed  ~    3s left
#   [attn_only/target] batch 2/2      6s elapsed  ~    0s left
#   [attn_only/target] done: 8 prompts in 6s
# attn_only: target=1.000  format=1.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 1191.99it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 427/427 [00:04<00:00, 93.86it/s]
#   [wrong_lr/target] batch 1/2     19s elapsed  ~   19s left
#   [wrong_lr/target] batch 2/2     38s elapsed  ~    0s left
#   [wrong_lr/target] done: 8 prompts in 38s
# wrong_lr: target=0.000  format=0.000
# Downloading bytes:           |  0.00B
# Reconstructing (incomplete total...): |          |  0.00B /  0.00B
#
# Fetching 4 files: 100% 4/4 [00:00<00:00, 1371.70it/s]
# Download complete: :           |  0.00B
# Download complete: :           |  0.00B
# Reconstruction complete: |          |  0.00B /  0.00B
# Loading weights: 100% 427/427 [00:04<00:00, 86.36it/s]
#   [qlora/target] batch 1/2      6s elapsed  ~    6s left
#   [qlora/target] batch 2/2     13s elapsed  ~    0s left
#   [qlora/target] done: 8 prompts in 13s
# qlora: target=1.000  format=1.000
#
# | run | target | format | latency_ms | n |
# |---|---|---|---|---|
# | correct | 1.0 | 1.0 | 1291.3 | 8 |
# | attn_only | 1.0 | 1.0 | 799.3 | 8 |
# | wrong_lr | 0.0 | 0.0 | 4701.4 | 8 |
# | qlora | 1.0 | 1.0 | 1609.8 | 8 |
# --- 3 ca TỆ NHẤT (bắt buộc đưa vào report) ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 0 | Cho mình hỏi, mình đặt chuột không dây mã đơn VN232232. Cho tôi trả lạ | 1.0 | {"intent": "doi_tra", "urgency": "cao", "product": "chuột không dây", "sentiment": "tich_c |
# | 1 | Shop ơi, mình đặt ốp lưng điện thoại mã đơn VN812931. Hoàn tiền. Sớm n | 1.0 | {"intent": "hoan_tien", "urgency": "trung_binh", "product": "ốp lưng điện thoại", "sentime |
# | 2 | Xin chào, mình đặt đèn bàn LED mã đơn VN880807. Hoàn tiền. Quá hạn rồi | 1.0 | {"intent": "hoan_tien", "urgency": "cao", "product": "đèn bàn LED", "sentiment": "tich_cuc |
#
# --- 3 ca TỐT NHẤT ---
# | i | ticket | ft_score | ft_pred |
# |---|---|---|---|
# | 5 | Shop ơi, mình đặt nồi chiên không dầu mã đơn DH249548. Thiếu phụ kiện. | 1.0 | {"intent": "san_pham_loi", "urgency": "thap", "product": "nồi chiên không dầu", "sentiment |
# | 6 | Xin chào, mình đặt balo laptop mã đơn DH863123. Đổi size. Hỏi cho biết | 1.0 | {"intent": "doi_tra", "urgency": "thap", "product": "balo laptop", "sentiment": "tieu_cuc" |
# | 7 | Alo shop, mình đặt máy xay sinh tố mã đơn OD126693. Muốn đổi. Đã 3 ngà | 1.0 | {"intent": "doi_tra", "urgency": "trung_binh", "product": "máy xay sinh tố", "sentiment":  |
#
# -- NB5 ok in 130s
#
# ----------------------------------------
# stage timings
#   nb1        19s  (0.3 min)
#   nb2       128s  (2.1 min)
#   nb3       474s  (7.9 min)
#   nb4      1395s  (23.3 min)
#   nb5       130s  (2.2 min)
#   total    2147s (35.8 min)

# %%
# @title 4. Gatekeeper + results
# !python scripts/verify.py
print("\n================ results/ ================")
# !ls -la results/
# !echo && echo "---- runs.csv ----" && cat results/runs.csv 2>/dev/null
# !echo && echo "---- verdict.json ----" && cat results/verdict.json 2>/dev/null
# Out:
# [  ok  ] labkit imports
# [  ok  ] tier resolves                                    BIGGPU -> Qwen/Qwen3.5-9B
# [  ok  ] all tiers respect the <32 effective-batch rule
# [  ok  ] data/train_seed.jsonl                            250 rows
# [  ok  ] data/eval_target.jsonl                           50 rows
# [  ok  ] data/eval_regression.jsonl                       15 rows
# [ FAIL ] unit tests                                       3 failed, 115 passed in 2.03s
# [  ok  ] results/template_check.json
# [  ok  ] results/mask_proof.json
# [  ok  ] results/token_stats.json
# [  ok  ] results/baselines_frozen.json
# [  ok  ] results/runs.csv
# [  ok  ] results/verdict.json
# [  ok  ] results/autopsy.json
# [  ok  ] submission/REPORT.md
# [ FAIL ] REPORT.md filled in                              6 placeholders still present (<điền>, <paste>, ...) — this is still the template
# [  ok  ] mask proof asserts
# [ FAIL ] full eval set used                               EVAL_LIMIT=8 — this run scored 8 target items, not the full set. Smoke mode is for iterating; unset EVAL_LIMIT and re-run NB2+NB5 to submit.
# [  ok  ] baseline (b) prompt unmodified
# [  ok  ] baseline (b) beats (a)                           (a)=0.000 -> (b)=0.844
# [  ok  ] eval sets unmodified
# [  ok  ] NB3 run present
# [  ok  ] NB4 contrast runs
# [  ok  ] all runs share ONE step budget                   ['attn_only', 'correct', 'qlora', 'wrong_lr'] at 30 steps
# [  ok  ] attn_only is a FAIR contrast                     43,311,104 vs 43,278,336 trainable params
# [  ok  ] verdict recorded                                 FAILED (target Δ +0.156, regression Δ -0.500)
# [ warn ] note                                             A FAILED verdict is fully gradeable — analyse it honestly in REPORT.md rather than loosening the gate.
#
# 23 passed · 1 warnings · 3 failures
#
# Not ready to submit — fix the FAILs above.
#
# ================ results/ ================
# total 40
# drwxr-xr-x  2 root root 4096 Aug 21 15:50 .
# drwxr-xr-x 15 root root 4096 Aug 21 15:14 ..
# -rw-r--r--  1 root root  426 Aug 21 15:50 autopsy.json
# -rw-r--r--  1 root root  481 Aug 21 15:17 baselines_frozen.json
# -rw-r--r--  1 root root    0 Aug 21 15:14 .gitkeep
# -rw-r--r--  1 root root  592 Aug 21 15:15 mask_proof.json
# -rw-r--r--  1 root root 2205 Aug 21 15:50 qualitative.json
# -rw-r--r--  1 root root 1102 Aug 21 15:48 runs.csv
# -rw-r--r--  1 root root  277 Aug 21 15:15 template_check.json
# -rw-r--r--  1 root root  115 Aug 21 15:15 token_stats.json
# -rw-r--r--  1 root root  768 Aug 21 15:49 verdict.json
#
# ---- runs.csv ----
# run,label,tier,model,precision,placement,n_target_modules,r,lora_alpha,learning_rate,load_in_4bit,trainable_params,train_seconds,peak_vram_gb,final_loss,mask_mode,max_steps,teaches
# correct,all-linear · r=16 · LR 10x · 16-bit,BIGGPU,Qwen/Qwen3.5-9B,bf16,text-linear,12,16,32,0.0001,False,43278336,445.0,23.26,0.281,assistant-only,30,
# attn_only,"q,v only · r=matched · LR 10x · 16-bit",BIGGPU,Qwen/Qwen3.5-9B,bf16,attn-only,2,311,622,0.0001,False,43311104,388.6,23.28,0.2607,,30,"Mistake #1 (§10.2): attention-only placement, rank raised to *match parameter count*. If rank were the lever, this would win."
# wrong_lr,all-linear · r=16 · LR 1x (full-FT scale) · 16-bit,BIGGPU,Qwen/Qwen3.5-9B,bf16,text-linear,12,16,32,1e-05,False,43278336,463.0,23.26,1.2069,,30,Mistake #2 (§10.3): a full-fine-tune learning rate applied to LoRA.
# qlora,all-linear · r=16 · LR 10x · 4-bit QLoRA,BIGGPU,Qwen/Qwen3.5-9B,bf16,text-linear,12,16,32,0.0001,True,43278336,492.4,13.3,0.2816,,30,The vendor says do NOT use QLoRA on Qwen3.5 (§12). Measure the cost yourself instead of taking either side on faith.
#
# ---- verdict.json ----
# {
#   "comparison": [
#     {
#       "run": "(a) base + naive prompt",
#       "target": 0.0,
#       "regression": 0.75,
#       "format": 0.0,
#       "latency_ms": 2868.3,
#       "n": 8
#     },
#     {
#       "run": "(b) base + optimized prompt",
#       "target": 0.8438,
#       "regression": 0.75,
#       "format": 1.0,
#       "latency_ms": 729.8,
#       "n": 8
#     },
#     {
#       "run": "(c) LoRA fine-tune",
#       "target": 1.0,
#       "regression": 0.25,
#       "format": 1.0,
#       "latency_ms": 1291.3,
#       "n": 8
#     }
#   ],
#   "verdict": {
#     "passed": false,
#     "reasons": [
#       "general capability regressed by 0.500 (tolerance 0.020). See deck §14.3 — add 1-5% replay data."
#     ],
#     "target_delta": 0.15625,
#     "regression_delta": -0.5
#   },
#   "valid_trace_rate": 0.0
# }
